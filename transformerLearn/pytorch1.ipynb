# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 print(torch.__VERSION)
#
# File d:\programFiles\anaconda3\envs\llm\lib\site-packages\torch\__init__.py:2681, in __getattr__(name)
#    2678 if name in _lazy_modules:
#    2679     return importlib.import_module(f".{name}", __name__)
# -> 2681 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute '__VERSION'
