# %%
import torch 

x=torch.tensor([
    [1,2,3],
    [4,5,6]
])
print(x)
print(x.ndim)
print(x.shape)
print(x.device)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])
# 2
# torch.Size([2, 3])
# cpu

# %%
torch.cuda.is_available()
# Out:
# False
