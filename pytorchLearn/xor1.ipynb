# %%
# %matplotlib inline
import torch 
import matplotlib.pyplot as plt

from torch import nn 



#X.shape (1000,2)
#y.shape(1000,1)

hidden_size=8
class XORModel(nn.Module):
    def __init__():
        super().__init__()
        self.params=a 
        hidden_num=8
        self.linear1=torch.randn((2,8))
        self.relu1=torch.nn.Relu()
        self.linear2=torch.rand((hidden_num,1))
        self.net=nn.Sequential(
            self.linear1,
            self.reul1,
            self.linear2,
        )



    def forward(self,X):
        #a
        y=  self.net(x)
        #logit 





EPOCH_SIZE=100
loss_fn=torch.loss 
optimizer=torch.optim.SGD(params=)
for i in EPOCH_SIZE:
    net=XORModel(X)
# Out:
#   Cell In[1], line 40
#     optimizer=torch.optim.SGD(params=)
#                                      ^
# SyntaxError: invalid syntax
