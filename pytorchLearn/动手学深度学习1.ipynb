# %%
import torch 

from torch import nn

# %%
net=nn.Sequential( nn.Linear(4,8),nn.ReLU(),nn.Linear(8,1))
X=torch.rand(size=(2,4))
a=net(X)
print(a)
print(net[2].state_dict())
# Out:
# tensor([[-0.2008],
#         [-0.1691]], grad_fn=<AddmmBackward0>)
# OrderedDict([('weight', tensor([[-0.2690,  0.0779,  0.0183,  0.0397,  0.2668, -0.0709,  0.3156,  0.0676]])), ('bias', tensor([-0.1350]))])
